# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('adult.data.csv')

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
lk = df['sex'] == 'male'
lk
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Name: sex, Length: 32561, dtype: bool

# %%
df["age"][df["sex"] == "Male"].mean()
# Out:
# 39.43354749885268

# %%
df["age"][df["sex"] == "Male"]
# Out:
# 0        39
# 1        50
# 2        38
# 3        53
# 7        52
#          ..
# 32553    32
# 32554    53
# 32555    22
# 32557    40
# 32559    22
# Name: age, Length: 21790, dtype: int64

# %% [markdown]
# what is the presentage of people who have bachelor

# %%
(len(df[df['education']== 'Bachelors'])/len(df)) * 100
# Out:
# 16.44605509658794

# %% [markdown]
# what percentage people with advance education make more than 50k

# %%
df[(df['education'].isin(['Bachelors','Masters','Doctorate'])) & (df['salary']=='>50K')]
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 8       31           Private   45781    Masters             14
# 9       42           Private  159449  Bachelors             13
# 11      30         State-gov  141297  Bachelors             13
# 19      43  Self-emp-not-inc  292175    Masters             14
# 20      40           Private  193524  Doctorate             16
# ...    ...               ...     ...        ...            ...
# 32533   54           Private  337992  Bachelors             13
# 32536   34           Private  160216  Bachelors             13
# 32538   38           Private  139180  Bachelors             13
# 32539   71                 ?  287372  Doctorate             16
# 32554   53           Private  321865    Masters             14
#
#            marital-status       occupation   relationship                race  \
# 8           Never-married   Prof-specialty  Not-in-family               White
# ...

# %%
df[(df['salary']== '>50K') & (df['education'].isin([ 'Bachelors', 'Masters', 'Doctorate']))]
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 8       31           Private   45781    Masters             14
# 9       42           Private  159449  Bachelors             13
# 11      30         State-gov  141297  Bachelors             13
# 19      43  Self-emp-not-inc  292175    Masters             14
# 20      40           Private  193524  Doctorate             16
# ...    ...               ...     ...        ...            ...
# 32533   54           Private  337992  Bachelors             13
# 32536   34           Private  160216  Bachelors             13
# 32538   38           Private  139180  Bachelors             13
# 32539   71                 ?  287372  Doctorate             16
# 32554   53           Private  321865    Masters             14
#
#            marital-status       occupation   relationship                race  \
# 8           Never-married   Prof-specialty  Not-in-family               White
# ...

# %%
df.shape
# Out:
# (32561, 15)

# %%
a =df[(df['salary']== '>50K') & (df['education']== 'Bachelors')]
b =df[(df['salary']== '>50K') & (df['education']== 'Masters')]
c= df[(df['salary']== '>50K') & (df['education']== 'Doctorate')]

# %%
(len(a)+len(b)+len(c))
# Out:
# 3486

# %%
hasil = (len(a)+len(b)+len(c))/ len(df)
hasil
# Out:
# 0.10706059396210191

# %%
a = df[~(df['education'].isin(['Bachelors','Masters','Doctorate'])) & (df['salary']=='>50K')]
hasil = len(a)/len(df)
hasil
# Out:
# 0.13374896348392248

# %%
a =df[(df['salary']== '>50K') & (df['native-country']== 'India')]

# %%
print(a['occupation'].mode()[0])
# Out:
# Prof-specialty
